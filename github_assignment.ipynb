# %%
import pandas as pd

file = pd.read_csv('/Users/miranda/Downloads/dataset4(1).csv')
file
# Out:
#          col0      col1      col2      col3      col4      col5      col6  \
# 0   -0.423261  1.620182 -0.915552 -0.263363 -1.207034  0.746682  2.064057
# 1    1.470107 -0.131548  1.562491 -1.032934  1.666673  0.325165 -0.515968
# 2    0.772825 -0.364077 -0.132575  0.548669  0.754104  2.332298  0.198543
# 3   -1.515417  0.110574  0.278613 -0.489525 -0.266813  1.268884  0.723024
# 4    0.945502 -2.352458 -0.780351 -0.672968  0.486584  0.461364 -0.803285
# ..        ...       ...       ...       ...       ...       ...       ...
# 357 -0.232960 -0.548420  0.935970  0.188334  0.840033  1.930337 -0.942390
# 358  0.351709 -0.225804 -0.489680 -1.311880 -0.409724 -0.906547  0.197991
# 359  0.594050 -1.517388  0.927374 -0.467275  1.660815  0.918972 -0.660550
# 360  0.368477 -1.010347 -0.855318  0.161107 -0.710622 -0.099878  1.531247
# 361  0.754021 -0.149618 -1.101164  0.000224  0.163761 -0.487047  0.060534
#
#          col7      col8      col9     col10     col11     col12     col13  \
# ...

# %%
plot = file['col0'].plot.line()
plot
# Out:
# <AxesSubplot:>
