# %%
# PEER VISUALIZATION 
# Dataset link -> https://www.kaggle.com/datasets/salvatorerastelli/spotify-and-youtube

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#US Visualization 
spotify_youtube = pd.read_csv("archive/Spotify_Youtube.csv")
spotify_youtube
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
#1 Daft Punk 
daft_punk = spotify_youtube.loc[spotify_youtube['Artist'] == 'Daft Punk']
daft_punk

dp_avg_dance = daft_punk['Danceability'].mean()
print("Daft Punk Avg Danceability: ", dp_avg_dance)

#2 Pitbull 
pitbull = spotify_youtube.loc[spotify_youtube['Artist'] == 'Pitbull']
pitbull

pb_avg_dance = pitbull['Danceability'].mean()
print("Pitbull Avg Danceability: ", pb_avg_dance)

#3 Luis Miguel
luis_miguel = spotify_youtube.loc[spotify_youtube['Artist'] == 'Luis Miguel']
luis_miguel

lm_avg_dance = luis_miguel['Danceability'].mean()
print("Luis Miguel Avg Danceability: ", lm_avg_dance)

#4 MGMT
MGMT = spotify_youtube.loc[spotify_youtube['Artist'] == 'MGMT']
MGMT

MGMT_avg_dance = MGMT['Danceability'].mean()
print("MGMT Avg Danceability: ", MGMT_avg_dance)

#Zedd
zedd = spotify_youtube.loc[spotify_youtube['Artist'] == 'Zedd']
zedd

zedd_avg_dance = zedd['Danceability'].mean()
print("Zedd Avg Danceability: ", zedd_avg_dance)

#Wolfgang Amadeus Mozart
mozart = spotify_youtube.loc[spotify_youtube['Artist'] == 'Wolfgang Amadeus Mozart']
mozart

mozart_avg_dance = mozart['Danceability'].mean()
print("Wolfgang Amadeus Mozart Avg Danceability: ", mozart_avg_dance)

data = [['Daft Punk', dp_avg_dance], ['Pitbull', pb_avg_dance], ['Luis Miguel', lm_avg_dance], 
        ['MGMT', MGMT_avg_dance], ['Zedd', zedd_avg_dance], ['Mozart', mozart_avg_dance]]
dance_df = pd.DataFrame(data, columns=['Artist', 'Average Dancebility']).sort_values('Average Dancebility', ascending=False)
# Out:
# Daft Punk Avg Danceability:  0.7721
# Pitbull Avg Danceability:  0.7011999999999999
# Luis Miguel Avg Danceability:  0.535
# MGMT Avg Danceability:  0.6175
# Zedd Avg Danceability:  0.6227
# Wolfgang Amadeus Mozart Avg Danceability:  0.2663

# %%
plt.bar(dance_df['Artist'], dance_df['Average Dancebility'],color=['blue', 'red', 'green', 'purple', 'cyan', 'orange'])
plt.xlabel("Artist")
plt.ylabel("Average Dancebility")
plt.title("My Favorite Artists and their Average Song Dancebility")
# Out:
# Text(0.5, 1.0, 'My Favorite Artists and their Average Song Dancebility')
